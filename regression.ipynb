# %% [markdown]
# <a href="https://colab.research.google.com/github/kurtlee1984/20210602/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_boston
boston = load_boston()
#dataFrame: 表格, series: 一行//一列
df = pd.DataFrame(boston["data"],
                  columns = boston["feature_names"])
df["ans"] = boston["target"]
df.to_csv("boston.csv", encoding="utf-8", index = False)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT   ans
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88  11.9
#
# ...

# %%
#回傳新值,會產生新表格,不影響原表格
df.drop(["ans"], axis=1)
#df_new = df.drop(["ans"], axis=1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %%
#原表格不影響
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT   ans
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88  11.9
#
# ...

# %%
# from sklearn.model_selection import train_test_split
# train_test_split([1, 2, 3, 4], test_size=0.25)
# train_test_split([1, 2, 3, 4],
#                  {5, 6, 7, 8],
#                   test_size=0.25)

# %%
#sklearn前,pandas.DataFrame
#sklearn後,np.arry
import numpy as np
from sklearn.model_selection import train_test_split
x, y = np.array(df.drop(["ans"], axis=1)), np.array(df["ans"])
# 90% x , 10%x ,90%y, 10%y
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(x_test.shape)
# Out:
# (455, 13)
# (51, 13)
# (455,)
# (51, 13)

# %%
#Decision Tree
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=3)
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=3,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 10 ))
plot_tree(reg,
          feature_names=boston["feature_names"],
          filled = True)
# Out:
# [Text(279.0, 475.65000000000003, 'RM <= 6.825\nmse = 87.253\nsamples = 455\nvalue = 22.604'),
#  Text(139.5, 339.75, 'LSTAT <= 14.4\nmse = 41.194\nsamples = 374\nvalue = 19.637'),
#  Text(69.75, 203.85000000000002, 'DIS <= 1.385\nmse = 27.224\nsamples = 217\nvalue = 23.196'),
#  Text(34.875, 67.94999999999999, 'mse = 78.146\nsamples = 5\nvalue = 45.58'),
#  Text(104.625, 67.94999999999999, 'mse = 13.928\nsamples = 212\nvalue = 22.668'),
#  Text(209.25, 203.85000000000002, 'CRIM <= 5.782\nmse = 18.787\nsamples = 157\nvalue = 14.717'),
#  Text(174.375, 67.94999999999999, 'mse = 10.89\nsamples = 83\nvalue = 17.325'),
#  Text(244.125, 67.94999999999999, 'mse = 11.458\nsamples = 74\nvalue = 11.792'),
#  Text(418.5, 339.75, 'RM <= 7.437\nmse = 71.622\nsamples = 81\nvalue = 36.302'),
#  Text(348.75, 203.85000000000002, 'NOX <= 0.659\nmse = 30.348\nsamples = 53\nvalue = 31.791'),
#  Text(313.875, 67.94999999999999, 'mse = 21.808\nsamples = 51\nvalue = 32.394'),
# ...

# %%
reg.predict(x_test)
# Out:
# array([22.66839623, 22.66839623, 22.66839623, 22.66839623, 17.3253012 ,
#        17.3253012 , 32.39411765, 17.3253012 , 17.3253012 , 17.3253012 ,
#        22.66839623, 11.79189189, 17.3253012 , 22.66839623, 17.3253012 ,
#        17.3253012 , 11.79189189, 22.66839623, 22.66839623, 22.66839623,
#        16.4       , 22.66839623, 45.69259259, 17.3253012 , 22.66839623,
#        32.39411765, 32.39411765, 22.66839623, 22.66839623, 22.66839623,
#        22.66839623, 22.66839623, 11.79189189, 22.66839623, 32.39411765,
#        22.66839623, 22.66839623, 22.66839623, 22.66839623, 22.66839623,
#        17.3253012 , 22.66839623, 17.3253012 , 22.66839623, 22.66839623,
#        22.66839623, 32.39411765, 45.69259259, 22.66839623, 11.79189189,
#        17.3253012 ])

# %%
from sklearn.metrics import r2_score
pre = reg.predict(x_test)
r2_score(y_test, pre)
# Out:
# 0.6557518092766291
