# %% [markdown]
# <a href="https://colab.research.google.com/github/kurtlee1984/Machine_Learning/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlretrieve
url = "https://github.com/kurtlee1984/Machine_Learning/raw/main/titanic_train.csv"
urlretrieve(url, "train.csv")
url = "https://github.com/kurtlee1984/Machine_Learning/raw/main/titanic_test.csv"
urlretrieve(url, "test.csv")
# Out:
# ('test.csv', <http.client.HTTPMessage at 0x7feec95cde50>)

# %%
import pandas as pd
train_df = pd.read_csv("train.csv", encoding="utf-8")
test_df = pd.read_csv("test.csv", encoding="utf-8")

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
data = pd.concat([train_df, test_df], ignore_index=True)
data = data.drop(["PassengerId", "Survived"], axis=1)

# %%
na = data.isna().sum()
#Series(帶入)
na[na > 0].sort_values(ascending=False)
# Out:
# Cabin       1014
# Age          263
# Embarked       2
# Fare           1
# dtype: int64

# %%
# s = pd.Series([1, 2, 3])
# s[[True, True, False]]

# %%
# s = pd.Series([1, 2, 3])
# # def func(n):
# #   return n * n
# # s.apply(func)
# s.apply(lambda n:n*n)

# %%
def cabin_head(s):
  if not pd.isna(s):
    return s[0]
# data["Cabin"].apply(cabin_head)
data["Cabin"] = data["Cabin"].apply(cabin_head)

# %%
dic = data["Ticket"].value_counts()
# data["Ticket"].apply(lambda t:dic[t])
data["Ticket"] = data["Ticket"].apply(lambda t:dic[t])

# %%
#補缺失值(類別: 最常出現)
most = data["Embarked"].value_counts().idxmax()
data["Embarked"] = data["Embarked"].fillna(most)
na = data.isna().sum()
na[na > 0].sort_values(ascending=False)
# Out:
# Cabin    1014
# Age       263
# Fare        1
# dtype: int64

# %%
##補缺失值(數值:中位數)
med = data.median().drop(["Pclass"])
data = data.fillna(med)
na = data.isna().sum()
na[na > 0].sort_values(ascending=False)
# Out:
# Cabin    1014
# dtype: int64

# %%
def name_convert(s):
    s = s.split(",")[-1].split(".")[0]
    s = s.strip()
    return s
counts = data["Name"].apply(name_convert).value_counts()
whitelist = counts[counts > 50].index
def name_convert(s):
    s = s.split(",")[-1].split(".")[0]
    s = s.strip()
    if s in whitelist:
        return s
    else:
        return None
data["Name"] = data["Name"].apply(name_convert)

# %%
data = pd.get_dummies(data)
data = pd.get_dummies(data, columns=["Pclass"])
data
# Out:
#        Age  SibSp  Parch  Ticket  ...  Embarked_S  Pclass_1  Pclass_2  Pclass_3
# 0     22.0      1      0       1  ...           1         0         0         1
# 1     38.0      1      0       2  ...           0         1         0         0
# 2     26.0      0      0       1  ...           1         0         0         1
# 3     35.0      1      0       2  ...           1         1         0         0
# 4     35.0      0      0       1  ...           1         0         0         1
# ...    ...    ...    ...     ...  ...         ...       ...       ...       ...
# 1304  28.0      0      0       1  ...           1         0         0         1
# 1305  39.0      0      0       3  ...           0         1         0         0
# 1306  38.5      0      0       1  ...           1         0         0         1
# 1307  28.0      0      0       1  ...           1         0         0         1
# 1308  28.0      1      1       3  ...           0         0         0         1
#
# ...

# %%
data["Family"] = data["SibSp"] + data["Parch"]
data
# Out:
#        Age  SibSp  Parch  Ticket  ...  Pclass_1  Pclass_2  Pclass_3  Family
# 0     22.0      1      0       1  ...         0         0         1       1
# 1     38.0      1      0       2  ...         1         0         0       1
# 2     26.0      0      0       1  ...         0         0         1       0
# 3     35.0      1      0       2  ...         1         0         0       1
# 4     35.0      0      0       1  ...         0         0         1       0
# ...    ...    ...    ...     ...  ...       ...       ...       ...     ...
# 1304  28.0      0      0       1  ...         0         0         1       0
# 1305  39.0      0      0       3  ...         1         0         0       0
# 1306  38.5      0      0       1  ...         0         0         1       0
# 1307  28.0      0      0       1  ...         0         0         1       0
# 1308  28.0      1      1       3  ...         0         0         1       2
#
# [1309 rows x 26 columns]
